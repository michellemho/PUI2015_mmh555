# %%
import zipfile
import pandas as pd
import os
import geopandas as gp
from scipy.cluster.vq import kmeans2
from scipy.cluster.vq import whiten
import numpy as np
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dataDir = '/Users/michelleho/PUI2015_mmh555/HW10/DATA'
dfs = {}
for subdir, dirs, files in os.walk(dataDir):
    for file in files[1:]:
        zf = zipfile.ZipFile(dataDir+'/'+file)
        dfs['{}'.format(os.path.splitext(file)[0][3:5]+'DF')] = pd.read_csv(zf.open(file.replace('.zip','.txt')))

# %%
#for x in dfs.keys():
#     print x

# %%
for x in dfs.keys():
    try:
        dfs['{}'.format(x)] = dfs['{}'.format(x)][['ZIP','EST']]
        dfs['{}'.format(x)].rename(columns={'EST': '{}'.format(x[0:2])+'EST'}, inplace=True)

    except KeyError:
            dfs['{}'.format(x)] = dfs['{}'.format(x)][['zip','est']]
            dfs['{}'.format(x)].rename(columns={'zip': 'ZIP', 'est': '{}'.format(x[0:2])+'EST'}, inplace=True)
    print dfs['{}'.format(x)].columns
# Out:
# Index([u'ZIP', u'06EST'], dtype='object')
# Index([u'ZIP', u'05EST'], dtype='object')
# Index([u'ZIP', u'02EST'], dtype='object')
# Index([u'ZIP', u'03EST'], dtype='object')
# Index([u'ZIP', u'99EST'], dtype='object')
# Index([u'ZIP', u'94EST'], dtype='object')
# Index([u'ZIP', u'13EST'], dtype='object')
# Index([u'ZIP', u'07EST'], dtype='object')
# Index([u'ZIP', u'97EST'], dtype='object')
# Index([u'ZIP', u'10EST'], dtype='object')
# Index([u'ZIP', u'98EST'], dtype='object')
# Index([u'ZIP', u'08EST'], dtype='object')
# Index([u'ZIP', u'12EST'], dtype='object')
# Index([u'ZIP', u'95EST'], dtype='object')
# Index([u'ZIP', u'11EST'], dtype='object')
# Index([u'ZIP', u'04EST'], dtype='object')
# Index([u'ZIP', u'96EST'], dtype='object')
# Index([u'ZIP', u'09EST'], dtype='object')

# %%
dfMergeExample = pd.merge(dfs['02DF'], dfs['03DF'], on='ZIP', how = 'inner')

# %%
dfsList = []
for x in dfs.keys():
    dfsList.append(dfs['{}'.format(x)])

#df_final = reduce(lambda left, right: pd.merge(left, right, on='ZIP'), dfs)

# %%
len(dfsList)
#We only have data from 1994 to 2013 in Zip Code total format, therefore we have 18 datasets, not 20
# Out:
# 18

# %%
df_final = reduce(lambda left, right: pd.merge(left, right, on='ZIP', how = 'inner'), dfsList)

# %%
shapeData = gp.read_file('NYCzipcodeshapefile2.geojson')

# %%
shapeData.rename(columns = {'postalCode':'ZIP'}, inplace=True)
#shapeData

# %%
shapeData['ZIP'] = shapeData['ZIP'].astype(float)
print type(shapeData['ZIP'][0])
# Out:
# <type 'numpy.float64'>

# %%
myData_merged = pd.merge(df_final, shapeData, on = 'ZIP', how = 'inner')
myData = myData_merged[myData_merged.columns[1:19]]
myData.head()
# Out:
#    06EST  05EST  02EST  03EST  99EST  94EST  13EST  07EST  97EST  10EST  \
# 0   7415   7312   7141   7084   7233   6999   7273   7549   7154   7241
# 1   2686   2682   2269   2402   2085   1784   2988   2685   2049   2872
# 2   3909   3867   3616   3704   3659   3256   4277   4049   3535   4113
# 3   1311   1260   1253   1252   1233   1115   1479   1370   1173   1398
# 4   1311   1260   1253   1252   1233   1115   1479   1370   1173   1398
#
#    98EST  08EST  12EST  95EST  11EST  04EST  96EST  09EST
# 0   7254   7472   7235   7088   7227   7370   7075   7305
# 1   2003   2691   2954   1819   2912   2551   1919   2775
# 2   3649   4071   4214   3377   4159   3776   3417   4099
# 3   1176   1376   1442   1124   1404   1283   1133   1379
# 4   1176   1376   1442   1124   1404   1283   1133   1379

# %%
for i in myData:
    #print myData[i].mean()
    #print myData[i].std()
    myData[i] = (myData[i] - myData[i].mean())/myData[i].std()
print myData.head()
# w = whiten(myData)
# w.head()
Nzipcodes = myData.shape[0]
Ntimestamps = myData.shape[1]
print "Number of zip codes: ", Nzipcodes
print "Number of time stamps: ", Ntimestamps
# Out:
#       06EST     05EST     02EST     03EST     99EST     94EST     13EST  \
# 0  5.283793  5.236400  5.236849  5.180049  5.285322  5.436639  5.128371
# 1  1.441795  1.451507  1.165044  1.267266  1.022426  0.873017  1.635005
# 2  2.435402  2.420211  2.290808  2.355358  2.325805  2.161157  2.685868
# 3  0.324699  0.289062  0.315916  0.306203  0.316912  0.287579  0.404786
# 4  0.324699  0.289062  0.315916  0.306203  0.316912  0.287579  0.404786
#
#       07EST     97EST     10EST     98EST     08EST     12EST     95EST  \
# 0  5.455895  5.275904  5.260357  5.302158  5.402986  5.160981  5.370861
# 1  1.456358  1.015283  1.614649  0.958882  1.460866  1.637573  0.868991
# 2  2.577939  2.255495  2.650200  2.320343  2.598729  2.674596  2.200157
# 3  0.375068  0.284175  0.384671  0.274843  0.376597  0.393146  0.275179
# 4  0.375068  0.284175  0.384671  0.274843  0.376597  0.393146  0.275179
#
#       11EST     04EST     96EST     09EST
# 0  5.219042  5.255943  5.338155  5.331392
# 1  1.632368  1.339224  0.943367  1.546832
# 2  2.668887  2.334862  2.220208  2.652960
# 3  0.378902  0.308637  0.273409  0.380553
# 4  0.378902  0.308637  0.273409  0.380553
# Number of zip codes:  243
# Number of time stamps:  18
# /Users/michelleho/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
nk= 5
for i in myData:
    figure = pl.figure
    cluster_centroids, closest_centroids = kmeans2(np.asarray(myData[i]), nk, iter=10)
    #print cluster_centroids
    pl.figure(figsize=(20,10))
    pl.hist(myData[i])
    pl.title('year {}'.format(i[0:2]))
    pl.xlabel('standard deviations from mean')
    for i in cluster_centroids:
        pl.axvline(cluster_centroids[i], linestyle='dashed', linewidth=1)
#myData.head()

# %%
myData['CLUSTER_{}'.format(i)] = closest_centroids
